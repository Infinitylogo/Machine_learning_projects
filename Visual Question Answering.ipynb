# %%
# !unzip '/content/drive/MyDrive/VQA/Questions_Train_abstract_v002.zip' -d ''
# Out:
# Archive:  /content/drive/MyDrive/VQA/Questions_Train_abstract_v002.zip
#   inflating: OpenEnded_abstract_v002_train2015_questions.json
#   inflating: MultipleChoice_abstract_v002_train2015_questions.json

# %%
import json
import pandas as pd
data = json.load(open('/content/OpenEnded_abstract_v002_train2015_questions.json'))

# %%
df=pd.DataFrame(data['questions'])

# %%
df.head()
# Out:
#                       question  image_id  question_id
# 0           Who looks happier?     11779       117792
# 1  Where is the woman sitting?     11779       117790
# 2    Where is the man sitting?     11779       117791
# 3          Is this man hungry?      5536        55360
# 4  What kind of drink is that?      5536        55361

# %%
data1 = json.load(open('/content/MultipleChoice_abstract_v002_train2015_questions.json'))

# %%
df1=pd.DataFrame(data1['questions'])

# %%
15177 in df1["image_id"]
# Out:
# True

# %%
df1.shape
# Out:
# (60000, 4)

# %%
df.shape
# Out:
# (60000, 3)

# %%
# !unzip '/content/drive/MyDrive/VQA/scene_img_abstract_v002_train2015.zip' -d 'data_img/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data_img/abstract_v002_train2015_000000015000.png
#   inflating: data_img/abstract_v002_train2015_000000015001.png
#   inflating: data_img/abstract_v002_train2015_000000015002.png
#   inflating: data_img/abstract_v002_train2015_000000015003.png
#   inflating: data_img/abstract_v002_train2015_000000015004.png
#   inflating: data_img/abstract_v002_train2015_000000015005.png
#   inflating: data_img/abstract_v002_train2015_000000015006.png
#   inflating: data_img/abstract_v002_train2015_000000015007.png
#   inflating: data_img/abstract_v002_train2015_000000015008.png
#   inflating: data_img/abstract_v002_train2015_000000015009.png
#   inflating: data_img/abstract_v002_train2015_000000015010.png
#   inflating: data_img/abstract_v002_train2015_000000015011.png
#   inflating: data_img/abstract_v002_train2015_000000015012.png
#   inflating: data_img/abstract_v002_train2015_000000015013.png
# ...

# %%
data_path='/content/data_img/'

# %%
import os 
len(os.listdir(data_path))
# Out:
# 20000

# %%
os.listdir(data_path)
# Out:
# ['abstract_v002_train2015_000000004542.png',
#  'abstract_v002_train2015_000000012776.png',
#  'abstract_v002_train2015_000000016692.png',
#  'abstract_v002_train2015_000000008513.png',
#  'abstract_v002_train2015_000000002634.png',
#  'abstract_v002_train2015_000000016982.png',
#  'abstract_v002_train2015_000000005572.png',
#  'abstract_v002_train2015_000000004295.png',
#  'abstract_v002_train2015_000000017778.png',
#  'abstract_v002_train2015_000000015248.png',
#  'abstract_v002_train2015_000000016467.png',
#  'abstract_v002_train2015_000000011766.png',
#  'abstract_v002_train2015_000000017157.png',
#  'abstract_v002_train2015_000000007324.png',
#  'abstract_v002_train2015_000000016800.png',
#  'abstract_v002_train2015_000000018137.png',
#  'abstract_v002_train2015_000000013326.png',
#  'abstract_v002_train2015_000000017383.png',
#  'abstract_v002_train2015_000000003769.png',
#  'abstract_v002_train2015_000000000973.png',
#  'abstract_v002_train2015_000000017675.png',
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('data_img/abstract_v002_train2015_000000019933.png')
imgplot = plt.imshow(img)
plt.show()
